# %% [markdown]
# # 서울에 전기차 충전소는 어디에 몇개가 필요해질까?
# - 26년까지 전기차를 40만대까지 늘린다고 하는데
# - 전기차 충전소 22만대를 보급한다고 했는데 충분한가
# - 그러면 전기차 충전소는 어디에 얼마나 필요해질까?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 지수표현식 제거하기
pd.options.display.float_format = '{:.5f}'.format

# %%
import koreanize_matplotlib
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## 서울시 전기차

# %%
file_name = ("서울특별시 행정동별 친환경자동차 현황-제원번호 포함 자료(2022.2.28).CSV")
raw = pd.read_csv(file_name, encoding='cp949')

# %%
raw = raw.loc[raw['연료'] == '전기', ['기준년월', '사용본거지시읍면동_행정동기준', '차명', '연료']]
raw = raw.rename(columns={"사용본거지시읍면동_행정동기준":"주소"})
raw = raw.dropna()

# %%
raw["구"] = raw["주소"].map(lambda x : x.split()[1])

# %% [markdown]
# ### 서울시 구별 전기차 수

# %%
df = raw.groupby("구")["차명"].count().sort_values(ascending=False).to_frame()
df = df.rename(columns={"차명" : "전기차수"})
df
# Out:
#        전기차수
# 구
# 강남구   12173
# 구로구    3799
# 서초구    3495
# 영등포구   2388
# 송파구    1988
# 강서구    1776
# 성동구    1461
# 강동구    1293
# 마포구    1086
# 양천구     998
# 용산구     968
# 중구      968
# 성북구     926
# 은평구     901
# 노원구     896
# 중랑구     778
# 관악구     777
# 동작구     726
# 서대문구    669
# 동대문구    659
# 도봉구     639
# 광진구     623
# 종로구     611
# 금천구     561
# 강북구     514

# %% [markdown]
# ### 서울시 총 전기차 수

# %%
df["전기차수"].sum()
# Out:
# 41673

# %% [markdown]
# ## 서울시 충전소

# %%
ev_raw = pd.read_excel("Data/f82bef3946130c05.xlsx")

# %%
ev_raw.head(2)
# Out:
#              운영기관              충전소      지역   시군구                 주소  \
# 0  환경부(한국자동차환경협회)     DMC 산학협력연구센터  서울특별시   마포구   서울특별시 마포구 매봉산로 37
# 1  환경부(한국자동차환경협회)  Park M (주차복합빌딩)  서울특별시   마포구   서울특별시 마포구 매봉산로 80
#
#           충전용량
# 0  급속(100kW멀티)
# 1  급속(200kW동시)

# %% [markdown]
# ### 서울시 구별 충전소 갯수

# %%
# 시군구로 count 해보기
ev_df = ev_raw.groupby("시군구")["충전소"].count().sort_values(ascending=False).to_frame()
# index 이름을 시군구에서 구로 변경
ev_df.index = ev_df.index.set_names("구")
ev_df
# Out:
#         충전소
# 구
# 강남구    2252
# 송파구    2106
# 서초구    1947
# 성동구    1756
# 강서구    1596
# 성북구    1483
# 마포구    1410
# 노원구    1353
# 구로구    1344
# 강동구    1272
# 영등포구   1228
# 중랑구    1218
# 은평구    1197
# 동작구    1036
# 금천구     958
# 중구      914
# 동대문구    903
# 양천구     899
# 서대문구    812
# 용산구     804
# 도봉구     702
# 강북구     622
# 종로구     604
# 관악구     594
# 광진구     546

# %% [markdown]
# ### 서울시 총 충전소 갯수

# %%
ev_df["충전소"].sum()
# Out:
# 29556

# %% [markdown]
# ### 두 df 합치기

# %%
# index 공백제거
ev_df.index = ev_df.index.str.strip()

# %%
df = df.merge(ev_df, left_index=True, right_index=True)
df
# Out:
#        전기차수   충전소
# 구
# 강남구   12173  2252
# 구로구    3799  1344
# 서초구    3495  1947
# 영등포구   2388  1228
# 송파구    1988  2106
# 강서구    1776  1596
# 성동구    1461  1756
# 강동구    1293  1272
# 마포구    1086  1410
# 양천구     998   899
# 용산구     968   804
# 중구      968   914
# 성북구     926  1483
# 은평구     901  1197
# 노원구     896  1353
# 중랑구     778  1218
# 관악구     777   594
# 동작구     726  1036
# 서대문구    669   812
# 동대문구    659   903
# 도봉구     639   702
# 광진구     623   546
# 종로구     611   604
# 금천구     561   958
# 강북구     514   622

# %% [markdown]
# ### 현재 충전소당 전기차 시각화

# %%
df["현재충전소당전기차"] = df["전기차수"] / df["충전소"]

# %%
plt.figure(figsize=(20,6))
sns.barplot(data=df, x=df.index, y="현재충전소당전기차", ci=None).set_title("현재충전소당전기차")
# Out:
# Text(0.5, 1.0, '현재충전소당전기차')

# %% [markdown]
# - 비율이 잘 안맞는 상태이다
# - 이 비율대로 전기차 충전소를 늘리면 큰 불편을 겪을 수도 있다.

# %% [markdown]
# # 미래 서울시 전기차는 총 40만대를 목표로 하고 있다.
# - 각 구에 몇대가 늘어나게 될까.
# - 그러면 현재 비율기준으로 전기차 충전소가 얼마나 필요할까.

# %%
# 현재 전기차 댓수 / 충전소갯수 / 전기차대충전소비율
df["전기차수"].sum() , df["충전소"].sum(), df["충전소"].sum() / df["전기차수"].sum()
# Out:
# (41673, 29556, 0.7092361960981931)

# %%
# 필요한 충전소 갯수 
ev_easy_count = round(400000 * (df["충전소"].sum() / df["전기차수"].sum()))
ev_easy_count
# Out:
# 283694

# %% [markdown]
# #### 서울시의 목표량과 비교

# %%
# 서울시의 목표량
seoul_ev = 220000 + df["충전소"].sum()
seoul_ev
# Out:
# 249556

# %%
# 부족해보이는 갯수
round(400000 * (df["충전소"].sum() / df["전기차수"].sum())) - (220000 + df["충전소"].sum())
# Out:
# 34138

# %% [markdown]
# ## 40만대가 될때 각 구별 전기차 수 예측

# %%
# 비율 * 40만대
df["미래전기차수"] = round((df["전기차수"] / df["전기차수"].sum()) * 400000).astype(int)

# %%
df
# Out:
#        전기차수   충전소  미래전기차수
# 구
# 강남구   12173  2252  116843
# 구로구    3799  1344   36465
# 서초구    3495  1947   33547
# 영등포구   2388  1228   22921
# 송파구    1988  2106   19082
# 강서구    1776  1596   17047
# 성동구    1461  1756   14023
# 강동구    1293  1272   12411
# 마포구    1086  1410   10424
# 양천구     998   899    9579
# 용산구     968   804    9291
# 중구      968   914    9291
# 성북구     926  1483    8888
# 은평구     901  1197    8648
# 노원구     896  1353    8600
# 중랑구     778  1218    7468
# 관악구     777   594    7458
# 동작구     726  1036    6969
# 서대문구    669   812    6421
# 동대문구    659   903    6325
# 도봉구     639   702    6133
# 광진구     623   546    5980
# 종로구     611   604    5865
# 금천구     561   958    5385
# 강북구     514   622    4934

# %% [markdown]
# ### 현재 충전소 분포 비율기준으로 미래 충전소 갯수

# %%
# 현재 기준 단순 예측
round((df["충전소"] / df["충전소"].sum()) * ev_easy_count).astype(int)
# Out:
# 구
# 강남구     21616
# 구로구     12900
# 서초구     18688
# 영등포구    11787
# 송파구     20214
# 강서구     15319
# 성동구     16855
# 강동구     12209
# 마포구     13534
# 양천구      8629
# 용산구      7717
# 중구       8773
# 성북구     14235
# 은평구     11489
# 노원구     12987
# 중랑구     11691
# 관악구      5702
# 동작구      9944
# 서대문구     7794
# 동대문구     8667
# 도봉구      6738
# 광진구      5241
# 종로구      5798
# 금천구      9195
# 강북구      5970
# Name: 충전소, dtype: int32

# %% [markdown]
# # 충전소 확충시 기존 주유소 분포를 참고하는게 좋은까 인구분포로 참고하는게 좋을까?
#
# 1주유소는 기존 자동차 수에 대해 충분히 분포하고 있다고 가정한다.
#
#
# 2 전기차는 인구밀도에도 영향이 있을 수 있다.
#
# ---
# - 주유소와 인구비 확인하기
# - 전기차충전소와 인구비 확인하기

# %% [markdown]
# ## 서울시 총 인구 데이터
# - 2021년 기준

# %%
people = pd.read_csv("Data/0_5________20221019173208.csv", encoding="cp949")
people.head(3)
# Out:
#    행정구역별(읍면동)     2021   2021.1   2021.2     2021.3      2021.4      2021.5  \
# 0  행정구역별(읍면동)  총인구 (명)   남자 (명)   여자 (명)  내국인-계 (명)  내국인-남자 (명)  내국인-여자 (명)
# 1       서울특별시  9472127  4584251  4887876    9125047     4421687     4703360
# 2         송파구   634720   305449   329271     624977      300957      324020
#
#       2021.6      2021.7      2021.8  ...    2021.10    2021.11     2021.12  \
# 0  외국인-계 (명)  외국인-남자 (명)  외국인-여자 (명)  ...  일반가구 (가구)  집단가구 (가구)  외국인가구 (가구)
# 1     347080      162564      184516  ...    4046799       2454      141918
# 2       9743        4492        5251  ...     259378         64        3828
#
#     2021.13   2021.14  2021.15   2021.16    2021.17          2021.18  \
# 0  주택-계 (호)  단독주택 (호)  아파트 (호)  연립주택 (호)  다세대주택 (호)  비거주용 건물내 주택 (호)
# 1   3068494    299473  1818214    110239     812403            28165
# 2    215731      7791   131487      4720      70238             1495
#
#         2021.19
# 0  주택이외의 거처 (호)
# 1        270052
# 2         18007
#
# [3 rows x 21 columns]

# %%
# 전처리
people = people[["행정구역별(읍면동)", "2021"]].iloc[2:]
people = people.reset_index(drop=True)
people = people.rename(columns={"행정구역별(읍면동)":"구","2021":"인구"})
people = people.set_index("구")
people
# Out:
#           인구
# 구
# 송파구   634720
# 강서구   559837
# 노원구   503929
# 강남구   503019
# 관악구   495777
# 은평구   457385
# 강동구   451099
# 성북구   435509
# 양천구   433373
# 구로구   426220
# 영등포구  402984
# 서초구   392302
# 동작구   388094
# 중랑구   380307
# 마포구   365192
# 동대문구  348201
# 광진구   347099
# 서대문구  314547
# 도봉구   309200
# 강북구   292611
# 성동구   286469
# 금천구   247398
# 용산구   221688
# 종로구   148857
# 중구    126310

# %%
# 숫자타입으로변경
people["인구"] = people["인구"].astype(int)

# %%
plt.figure(figsize=(20,6))
sns.barplot(data=people, x=people.index, y="인구", ci=None).set_title("인구")
# Out:
# Text(0.5, 1.0, '인구')

# %% [markdown]
# ## 서울시 주유소 데이터

# %%
oil = pd.read_csv("Data/서울시주유소.csv", encoding="cp949")
oil.head()
# Out:
#    연번 자치구명                주유소명                     주소
# 0   1  용산구  현대오일뱅크(주) 직영소월길주유소        서울특별시 용산구 소월로66
# 1   2  용산구      선익상사(주) 동자동주유소  서울특별시 용산구 한강대로 104길 6
# 2   3  용산구    현대오일뱅크㈜ 직영갈월동주유소     서울특별시 용산구 한강대로 322
# 3   4  용산구               서계주유소      서울특별시 용산구 청파로 367
# 4   5  용산구        ㈜영원에너지 풍기주유소       서울특별시 용산구 원효로178

# %%
oil_df = oil.groupby("자치구명")[["주유소명"]].count()

# %%
oil_df.index = oil_df.index.set_names("구")

# %%
oil_df = oil_df.rename(columns={"주유소명":"주유소갯수"})

# %% [markdown]
# ### 서울시 구별 주유소 갯수

# %%
oil_df
# Out:
#       주유소갯수
# 구
# 강남구      35
# 강동구      14
# 강북구      13
# 강서구      32
# 관악구      15
# 광진구      16
# 구로구      21
# 금천구      12
# 노원구      15
# 도봉구      18
# 동대문구     19
# 동작구      10
# 마포구      12
# 서대문구     15
# 서초구      33
# 성동구      17
# 성북구      24
# 송파구      33
# 양천구      25
# 영등포구     29
# 용산구      13
# 은평구      17
# 종로구       9
# 중구       11
# 중랑구      15

# %% [markdown]
# ### 인구와 주유소데이터 합치기

# %%
df_op = people.merge(oil_df, left_index=True, right_index=True)
df_op
# Out:
#           인구  주유소갯수
# 구
# 송파구   634720     33
# 강서구   559837     32
# 노원구   503929     15
# 강남구   503019     35
# 관악구   495777     15
# 은평구   457385     17
# 강동구   451099     14
# 성북구   435509     24
# 양천구   433373     25
# 구로구   426220     21
# 영등포구  402984     29
# 서초구   392302     33
# 동작구   388094     10
# 중랑구   380307     15
# 마포구   365192     12
# 동대문구  348201     19
# 광진구   347099     16
# 서대문구  314547     15
# 도봉구   309200     18
# 강북구   292611     13
# 성동구   286469     17
# 금천구   247398     12
# 용산구   221688     13
# 종로구   148857      9
# 중구    126310     11

# %% [markdown]
# ### 전기차 데이터와 합치기

# %%
df = df_op.merge(df, left_index=True, right_index=True)
df
# Out:
#           인구  주유소갯수   전기차수   충전소  미래전기차수
# 구
# 송파구   634720     33   1988  2106   19082
# 강서구   559837     32   1776  1596   17047
# 노원구   503929     15    896  1353    8600
# 강남구   503019     35  12173  2252  116843
# 관악구   495777     15    777   594    7458
# 은평구   457385     17    901  1197    8648
# 강동구   451099     14   1293  1272   12411
# 성북구   435509     24    926  1483    8888
# 양천구   433373     25    998   899    9579
# 구로구   426220     21   3799  1344   36465
# 영등포구  402984     29   2388  1228   22921
# 서초구   392302     33   3495  1947   33547
# 동작구   388094     10    726  1036    6969
# 중랑구   380307     15    778  1218    7468
# 마포구   365192     12   1086  1410   10424
# 동대문구  348201     19    659   903    6325
# 광진구   347099     16    623   546    5980
# 서대문구  314547     15    669   812    6421
# 도봉구   309200     18    639   702    6133
# 강북구   292611     13    514   622    4934
# 성동구   286469     17   1461  1756   14023
# 금천구   247398     12    561   958    5385
# 용산구   221688     13    968   804    9291
# 종로구   148857      9    611   604    5865
# 중구    126310     11    968   914    9291

# %%
df.corr()
# Out:
#             인구   주유소갯수    전기차수     충전소  미래전기차수
# 인구     1.00000 0.64937 0.31910 0.57080 0.31910
# 주유소갯수  0.64937 1.00000 0.61087 0.71821 0.61087
# 전기차수   0.31910 0.61087 1.00000 0.63939 1.00000
# 충전소    0.57080 0.71821 0.63939 1.00000 0.63939
# 미래전기차수 0.31910 0.61087 1.00000 0.63939 1.00000

# %%
sns.heatmap(df.corr(), cmap="Greens")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 중간인사이트
# - 주유소와 충전소의 갯수가 인구보다 더 상관관계에 있다.
# - 인구에 비례하게 하기보다는, 주유소의 비율로 충전소를 늘리는게 더 유의미하다고 생각했다.
# - 휘발유차 대비 얼만큼의 주유소가 있는지 확인해보자

# %% [markdown]
# ## 서울시 휘발유 자동차 데이터

# %%
car_raw = pd.read_csv("Data/21년서울시 자동차 등록현황(동별 연료별).csv", encoding="cp949")
car_raw = car_raw[4:]

# %%
car_raw["구"] =  car_raw["행정동-연료별 분류"].map(lambda x : x.split()[1].strip())

# %%
car_df = car_raw[["구","경유","하이브리드(경유-전기)","하이브리드(휘발유-전기)","휘발유","휘발유(무연)","휘발유(유연)"]]
car_df
# Out:
#        구         경유  하이브리드(경유-전기)  하이브리드(휘발유-전기)        휘발유    휘발유(무연)  \
# 4    강남구 1178.00000       1.00000      190.00000  917.00000 1058.00000
# 5    강남구 2714.00000      10.00000      624.00000 2949.00000 2947.00000
# 6    강남구 2722.00000       6.00000      464.00000 2230.00000 2612.00000
# 7    강남구 3608.00000       9.00000      416.00000 2661.00000 3309.00000
# 8    강남구 3646.00000      15.00000      376.00000 2964.00000 2791.00000
# ..   ...        ...           ...            ...        ...        ...
# 448  중랑구 1944.00000       4.00000      166.00000 1008.00000 1787.00000
# 449  중랑구 4806.00000       6.00000      421.00000 2126.00000 3821.00000
# 450  중랑구 2370.00000       2.00000      219.00000 1157.00000 2130.00000
# 451  중랑구 2112.00000       2.00000      142.00000  965.00000 1800.00000
# 452  중랑구 2432.00000           NaN      133.00000 1073.00000 1812.00000
#
#      휘발유(유연)
# 4    2.00000
# 5    5.00000
# 6    3.00000
# 7    3.00000
# 8    4.00000
# ..       ...
# 448  3.00000
# 449  3.00000
# 450  3.00000
# 451  2.00000
# 452  2.00000
#
# [449 rows x 7 columns]

# %%
# 결측치 확인
car_df.isnull().sum()
# Out:
# 구                 0
# 경유                3
# 하이브리드(경유-전기)     75
# 하이브리드(휘발유-전기)    22
# 휘발유              12
# 휘발유(무연)           9
# 휘발유(유연)          89
# dtype: int64

# %%
# 결측치를 0으로 변경
car_df = car_df.fillna(0)

# %%
# 구별로 묶어주기
car_df = car_df.groupby("구").sum()

# %%
car_df["휘발유자동차수"] = car_df.sum(axis=1).astype(int)

# %%
car_df
# Out:
#               경유  하이브리드(경유-전기)  하이브리드(휘발유-전기)         휘발유     휘발유(무연)  \
# 구
# 강남구  68250.00000     286.00000    15256.00000 65853.00000 66798.00000
# 강동구  51743.00000      87.00000     6512.00000 30220.00000 47616.00000
# 강북구  27457.00000      23.00000     2119.00000 13196.00000 23432.00000
# 강서구  69132.00000      96.00000    10387.00000 38463.00000 63633.00000
# 관악구  41324.00000      36.00000     4327.00000 22432.00000 38518.00000
# 광진구  36063.00000      90.00000     3690.00000 20229.00000 29805.00000
# 구로구  53887.00000      43.00000     4847.00000 24688.00000 44649.00000
# 금천구  36609.00000      49.00000     2784.00000 14130.00000 27535.00000
# 노원구  49714.00000      39.00000     5446.00000 28313.00000 50268.00000
# 도봉구  33439.00000      36.00000     2808.00000 16817.00000 30173.00000
# 동대문구 36406.00000      63.00000     3386.00000 19040.00000 29954.00000
# 동작구  34510.00000      62.00000     4806.00000 23454.00000 35112.00000
# 마포구  41468.00000      90.00000     5354.00000 26778.00000 37589.00000
# 서대문구 29733.00000      51.00000     3722.00000 18466.00000 28602.00000
# 서초구  55780.00000     144.00000     9693.00000 48646.00000 52093.00000
# 성동구  36747.00000     112.00000     4266.00000 21666.00000 33474.00000
# 성북구  41912.00000      62.00000     4652.00000 24553.00000 38750.00000
# 송파구  85865.00000     186.00000    11384.00000 55351.00000 73759.00000
# 양천구  50228.00000      74.00000     5974.00000 32153.00000 47399.00000
# 영등포구 53832.00000      74.00000     6240.00000 29317.00000 44080.00000
# 용산구  25138.00000      67.00000     3838.00000 23227.00000 22450.00000
# 은평구  44612.00000      44.00000     4709.00000 26134.00000 42880.00000
# 종로구  18114.00000      29.00000     2367.00000 10974.00000 15251.00000
# 중구   24110.00000      72.00000     2491.00000 17068.00000 13553.00000
# 중랑구  42946.00000      48.00000     3168.00000 19056.00000 34298.00000
#
#       휘발유(유연)  휘발유자동차수
# 구
# 강남구  89.00000   216532
# 강동구  57.00000   136235
# 강북구  20.00000    66247
# 강서구  66.00000   181777
# 관악구  55.00000   106692
# 광진구  32.00000    89909
# 구로구  42.00000   128156
# 금천구  39.00000    81146
# 노원구  48.00000   133828
# 도봉구  35.00000    83308
# 동대문구 30.00000    88879
# 동작구  35.00000    97979
# 마포구  34.00000   111313
# 서대문구 30.00000    80604
# 서초구  54.00000   166410
# 성동구  42.00000    96307
# 성북구  38.00000   109967
# 송파구  97.00000   226642
# 양천구  42.00000   135870
# 영등포구 62.00000   133605
# 용산구  17.00000    74737
# 은평구  46.00000   118425
# 종로구  11.00000    46746
# 중구   11.00000    57305
# 중랑구  37.00000    99553

# %% [markdown]
# ### 구별 휘발유 자동차 수

# %%
car_df = car_df[["휘발유자동차수"]]
car_df
# Out:
#       휘발유자동차수
# 구
# 강남구    216532
# 강동구    136235
# 강북구     66247
# 강서구    181777
# 관악구    106692
# 광진구     89909
# 구로구    128156
# 금천구     81146
# 노원구    133828
# 도봉구     83308
# 동대문구    88879
# 동작구     97979
# 마포구    111313
# 서대문구    80604
# 서초구    166410
# 성동구     96307
# 성북구    109967
# 송파구    226642
# 양천구    135870
# 영등포구   133605
# 용산구     74737
# 은평구    118425
# 종로구     46746
# 중구      57305
# 중랑구     99553

# %% [markdown]
# ### df 와 합치기

# %%
df = df.merge(car_df, left_index=True, right_index=True)
df
# Out:
#           인구  주유소갯수   전기차수   충전소  미래전기차수  휘발유자동차수
# 구
# 송파구   634720     33   1988  2106   19082   226642
# 강서구   559837     32   1776  1596   17047   181777
# 노원구   503929     15    896  1353    8600   133828
# 강남구   503019     35  12173  2252  116843   216532
# 관악구   495777     15    777   594    7458   106692
# 은평구   457385     17    901  1197    8648   118425
# 강동구   451099     14   1293  1272   12411   136235
# 성북구   435509     24    926  1483    8888   109967
# 양천구   433373     25    998   899    9579   135870
# 구로구   426220     21   3799  1344   36465   128156
# 영등포구  402984     29   2388  1228   22921   133605
# 서초구   392302     33   3495  1947   33547   166410
# 동작구   388094     10    726  1036    6969    97979
# 중랑구   380307     15    778  1218    7468    99553
# 마포구   365192     12   1086  1410   10424   111313
# 동대문구  348201     19    659   903    6325    88879
# 광진구   347099     16    623   546    5980    89909
# 서대문구  314547     15    669   812    6421    80604
# 도봉구   309200     18    639   702    6133    83308
# 강북구   292611     13    514   622    4934    66247
# 성동구   286469     17   1461  1756   14023    96307
# 금천구   247398     12    561   958    5385    81146
# 용산구   221688     13    968   804    9291    74737
# 종로구   148857      9    611   604    5865    46746
# 중구    126310     11    968   914    9291    57305

# %% [markdown]
# ### 주유소당 휘발유자동차 수

# %%
df["주유소당자동차"] = df["휘발유자동차수"] / df["주유소갯수"]

# %% [markdown]
# ### 자동차당 주유소

# %%
df["자동차당주유소비율"] = df["주유소갯수"] / df["휘발유자동차수"] * 100

# %%
df
# Out:
#           인구  주유소갯수   전기차수   충전소  미래전기차수  휘발유자동차수    주유소당자동차  자동차당주유소비율
# 구
# 송파구   634720     33   1988  2106   19082   226642 6867.93939    0.01456
# 강서구   559837     32   1776  1596   17047   181777 5680.53125    0.01760
# 노원구   503929     15    896  1353    8600   133828 8921.86667    0.01121
# 강남구   503019     35  12173  2252  116843   216532 6186.62857    0.01616
# 관악구   495777     15    777   594    7458   106692 7112.80000    0.01406
# 은평구   457385     17    901  1197    8648   118425 6966.17647    0.01436
# 강동구   451099     14   1293  1272   12411   136235 9731.07143    0.01028
# 성북구   435509     24    926  1483    8888   109967 4581.95833    0.02182
# 양천구   433373     25    998   899    9579   135870 5434.80000    0.01840
# 구로구   426220     21   3799  1344   36465   128156 6102.66667    0.01639
# 영등포구  402984     29   2388  1228   22921   133605 4607.06897    0.02171
# 서초구   392302     33   3495  1947   33547   166410 5042.72727    0.01983
# 동작구   388094     10    726  1036    6969    97979 9797.90000    0.01021
# 중랑구   380307     15    778  1218    7468    99553 6636.86667    0.01507
# 마포구   365192     12   1086  1410   10424   111313 9276.08333    0.01078
# 동대문구  348201     19    659   903    6325    88879 4677.84211    0.02138
# 광진구   347099     16    623   546    5980    89909 5619.31250    0.01780
# 서대문구  314547     15    669   812    6421    80604 5373.60000    0.01861
# 도봉구   309200     18    639   702    6133    83308 4628.22222    0.02161
# 강북구   292611     13    514   622    4934    66247 5095.92308    0.01962
# 성동구   286469     17   1461  1756   14023    96307 5665.11765    0.01765
# 금천구   247398     12    561   958    5385    81146 6762.16667    0.01479
# 용산구   221688     13    968   804    9291    74737 5749.00000    0.01739
# 종로구   148857      9    611   604    5865    46746 5194.00000    0.01925
# 중구    126310     11    968   914    9291    57305 5209.54545    0.01920

# %% [markdown]
# ## 자동차당주유소 비율에 맞게 전기차 충전소를 배치해보자

# %%
# 서울시가 목표로 하는 충전소갯수
seoul_ev
# Out:
# 249556

# %%
# 자동차당주유소비율로 전기차 충전소 갯수 추천
(df["자동차당주유소비율"] * df["미래전기차수"] * 37).sum()
# Out:
# 248512.64272766135

# %%
df["주유소비율로본미래충전소갯수"] = (df["자동차당주유소비율"] * df["미래전기차수"] * 37)

# %%
plt.figure(figsize=(20,6))
sns.barplot(data=df, x=df.index, y="주유소비율로본미래충전소갯수", ci=None).set_title("주유소비율로본미래충전소갯수")
# Out:
# Text(0.5, 1.0, '주유소비율로본미래충전소갯수')

# %%
df["미래충전소당전기차예측(주유소기준)"] = df["미래전기차수"] / df["주유소비율로본미래충전소갯수"]
df["미래충전소당전기차예측(주유소기준)"]
# Out:
# 구
# 송파구    1.85620
# 강서구    1.53528
# 노원구    2.41132
# 강남구    1.67206
# 관악구    1.92238
# 은평구    1.88275
# 강동구    2.63002
# 성북구    1.23837
# 양천구    1.46886
# 구로구    1.64937
# 영등포구   1.24515
# 서초구    1.36290
# 동작구    2.64808
# 중랑구    1.79375
# 마포구    2.50705
# 동대문구   1.26428
# 광진구    1.51873
# 서대문구   1.45232
# 도봉구    1.25087
# 강북구    1.37728
# 성동구    1.53111
# 금천구    1.82761
# 용산구    1.55378
# 종로구    1.40378
# 중구     1.40799
# Name: 미래충전소당전기차예측(주유소기준), dtype: float64

# %%
plt.figure(figsize=(20,6))
sns.barplot(data=df, x=df.index, y="미래충전소당전기차예측(주유소기준)", ci=None).set_title("미래충전소당전기차예측(주유소기준)")
# Out:
# Text(0.5, 1.0, '미래충전소당전기차예측(주유소기준)')

# %% [markdown]
# ### 만약 인구비로 충전소를 늘린다면?
# - 인구가 많은 쪽에 충전소를 늘려야 한다고 접근하면 어떻게 될까?

# %%
df["인구비"] = df["인구"] / df["인구"].sum()

# %%
seoul_ev
# Out:
# 249556

# %%
(df["인구비"] * df["미래전기차수"] * 13.7).sum()
# Out:
# 249381.5231770858

# %%
df["인구비율로본미래충전소갯수"] = (df["인구비"] * df["미래전기차수"] * 13.7)

# %%
plt.figure(figsize=(20,6))
sns.barplot(data=df, x=df.index, y="인구비율로본미래충전소갯수", ci=None).set_title("인구비율로본미래충전소갯수")
# Out:
# Text(0.5, 1.0, '인구비율로본미래충전소갯수')

# %%
df["미래충전소당전기차예측(인구기준)"] = df["미래전기차수"] / df["인구비율로본미래충전소갯수"]

# %%
plt.figure(figsize=(20,6))
sns.barplot(data=df, x=df.index, y="미래충전소당전기차예측(인구기준)", ci=None).set_title("미래충전소당전기차예측(인구기준)")
# Out:
# Text(0.5, 1.0, '미래충전소당전기차예측(인구기준)')

# %% [markdown]
# - 인구비로 늘렸을때는, 종로구, 중구 등에서 전기차 예상수요를 따라가지 못하는걸로 보인다.
